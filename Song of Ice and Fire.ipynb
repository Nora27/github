# %%
# %load_ext hierarchymagic

# %%
# %%dot -f svg
# digraph {
#     node [fontcolor=gold shape=square]
#         Jaime [label="Jaime Lannister"]
#         Cersei [label="Cersei Lannister"]
#         Tyrion [label="Tyrion Lannister"]
#         Tywin [label="Tywin Lannister"]
#     node [fontcolor=darkred shape=square]
#         Tommen [label="Tommen Baratheon"]
#         Myrcella [label="Myrcella Baratheon"]
#         Joffrey [label="Joffrey Baratheon (dead)"]
#         Robert [label="Robert Baratheon (dead)"]
#         Renly [label="Renly Baratheon"]
#         Stannis [label="Stannis Baratheon"]
#         "king/queen" [color=yellow fontcolor=black shape=star]
#             Cersei -> Tommen [label="mother" color=gold]
#             Jaime -> Tommen [label="father" color=gold]
#             Cersei -> Myrcella [label="mother" color=gold]
#             Jaime -> Myrcella [label="father" color=gold]
#             Cersei -> Joffrey [label="mother" color=gold]
#             Jaime -> Joffrey [label="father" color=gold]
#             Joffrey -> Myrcella [label="siblings" arrowhead=none color=gold]
#             Joffrey -> Tommen [label="siblings" arrowhead=none color=gold]
#             Tommen -> Myrcella [label="siblings" arrowhead=none color=gold]
#             Tommen -> "king/queen" [label="is" color=yellow]
#             Cersei -> Jaime [label="twins" arrowhead=none color=gold]
#             Cersei -> Robert [label="married" arrowhead=none color=deeppink4]
#             Tyrion -> Cersei [label="siblings" arrowhead=none color=gold]
#             Tyrion -> Jaime [label="siblings" arrowhead=none color=gold]
#             Renly -> Robert [label="siblings" arrowhead=none color=darkred]
#             Stannis -> Robert [label="siblings" arrowhead=none color=darkred]
#             Renly -> Stannis [label="siblings" arrowhead=none color=darkred]
#             Tywin -> Cersei [label="father" color=gold]
#             Tywin -> Jaime [label="father" color=gold]
#             Tywin -> Tyrion [label="father" color=gold]
#     node [fontcolor=black shape=square]
#         Jon [label="Jon Snow"]
#     node [fontcolor=grey41 shape=square]
#         Sansa [label="Sansa Stark"]
#         Arya [label="Arya Stark"]
#         Robb [label="Robb Stark (dead)"]
#         Rickon [label="Rickon Stark"]
#         Bran [label="Bran Stark"]
#         Eddard [label="Eddard Stark (dead)"]
#     node [fontcolor=navy shape=square]
#         Catelyn [label="Catelyn Tully (dead)"]
#         Lysa [label="Lysa Tully (dead)"]
#         Edmure [label="Edmure Tully"]
#         Hoster [label="Hoster Tully (dead)"]
#         Brynden [label="Brynden 'Blackfish' Tully"]
#     node [fontcolor=grey shape=circle]
#         Grey [label="Grey Wind (dead)"]
#         Ghost [label=Ghost]
#         Lady [label="Lady (dead)"]
#         Nymeria [label=Nymeria]
#         Summer [label=Summer]
#         Shaggydog [label=Shaggydog]
#      node [fontcolor=teal shape=square]
#         Hodor [label=Hodor]
#         Hodor2 [label="Hodor!"]
#             Hodor -> Hodor2 [label="says" color=teal]
#             Catelyn -> Sansa [label="mother" color=grey41]
#             Eddard -> Sansa [label="father" color=grey41]
#             Catelyn -> Arya [label="mother" color=grey41]
#             Eddard -> Arya [label="father" color=grey41]
#             Catelyn -> Robb [label="mother" color=grey41]
#             Eddard -> Robb [label="father" color=grey41]
#             Eddard -> Jon [label="father"]
#             Catelyn -> Rickon [label="mother" color=grey41]
#             Eddard -> Rickon [label="father" color=grey41]
#             Catelyn -> Bran [label="mother" color=grey41]
#             Eddard -> Bran [label="father" color=grey41]
#             Robb -> "king/queen" [label="was" color=yellow]
#             Sansa -> Joffrey [label="have been betrothed" arrowhead=none style=dotted color=deeppink4]
#             Eddard -> Catelyn [label="married" arrowhead=none color=deeppink4]
#             Ghost -> Jon [label="pet direwolf" color=grey]
#             Summer -> Bran [label="pet direwolf" color=grey]
#             Lady -> Sansa [label="pet direwolf" color=grey]
#             Nymeria -> Arya [label="pet direwolf" color=grey]
#             Shaggydog -> Rickon [label="pet direwolf" color=grey]
#             Grey -> Robb [label="pet direwolf" color=grey]
#             Edmure -> Catelyn [label="siblings" arrowhead=none color=navy]
#             Brynden -> Catelyn [label="siblings" arrowhead=none color=navy]
#             Hoster -> Catelyn [label="father" color=navy]
#             Hoster -> Brynden [label="father" color=navy]
#             Hoster -> Edmure [label="father" color=navy]
#             Hoster -> Lysa [label="father" color=navy]
#             Brynden -> Lysa [label="siblings" arrowhead=none color=navy]
#             Brynden -> Edmure [label="siblings" arrowhead=none color=navy]
#             Lysa -> Edmure [label="siblings" arrowhead=none color=navy]
#             Lysa -> Catelyn [label="siblings" arrowhead=none color=navy]
#     node [fontcolor=springgreen4 shape=square]
#         Margaery [label="Margaery Tyrell"]
#         Loras [label="Loras Tyrell"]
#             Margaery -> Tommen [label="married" arrowhead=none color=deeppink4]
#             Margaery -> Joffrey [label="have been married" arrowhead=none style=dotted color=deeppink4]
#             Margaery -> Loras [label="siblings" arrowhead=none]
#     node [fontcolor=orangered shape=square]
#         Daenerys [label="Daenerys Targaryen"]
#         Viserys [label="Viserys Targaryen (dead)"]
#     node [fontcolor=saddlebrown shape=square]
#         Drogo [label="Khal Drogo (dead)"]
#         Hizdahr [label="Hizdahr Zo Loraq"]
#     node [fontcolor=darkorange shape=circle]
#         Drogon [label=Drogon]
#         Viserion [label=Viserion]
#         Rhaegal [label=Rhaegal]
#             Daenerys -> Hizdahr [label="married" arrowhead=none color=deeppink4]
#             Daenerys -> Drogo [label="have been married" arrowhead=none style=dotted color=deeppink4]
#             Daenerys -> Viserys [label="siblings" arrowhead=none color=orangered]
#             Daenerys -> "king/queen" [label="is" color=yellow]
#             Drogon -> Daenerys [label="pet dragon" color=darkorange]
#             Viserion -> Daenerys [label="pet dragon" color=darkorange]
#             Rhaegal -> Daenerys [label="pet dragon" color=darkorange]
# }
